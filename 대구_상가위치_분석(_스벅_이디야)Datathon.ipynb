# %% [markdown]
# <a href="https://colab.research.google.com/github/reparadise/DATATHON/blob/main/%EB%8C%80%EA%B5%AC_%EC%83%81%EA%B0%80%EC%9C%84%EC%B9%98_%EB%B6%84%EC%84%9D(_%EC%8A%A4%EB%B2%85_%EC%9D%B4%EB%94%94%EC%95%BC)Datathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, sys

from os.path import join
import pandas as pd

data_dir = '/content/drive/MyDrive/Colab Notebooks1/소상공인시장진흥공단_상가(상권)정보_대구_202203.csv'
data = pd.read_csv(data_dir)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (35) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data.head()
# Out:
#      상가업소번호      상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명 상권업종소분류코드  \
# 0  20547760   옛날포장마차  NaN         Q       음식       Q09       유흥주점    Q09A02
# 1  23801062  으뜸전산컴퓨터  NaN         D       소매       D08  사무/문구/컴퓨터    D08A03
# 2  20549469     박가냉면  NaN         Q       음식       Q01         한식    Q01A01
# 3  24513354      종합꽃  NaN         D       소매       D02  선물/팬시/기념품    D02A02
# 4  17174605   장충동왕족발  NaN         Q       음식       Q01         한식    Q01A08
#
#       상권업종소분류명 표준산업분류코드  ...                     건물관리번호     건물명  \
# 0     소주방/포장마차   I56219  ...  2717010200113270001025963     NaN
# 1  컴퓨터/사무용기기종합   G47311  ...  2729010200101500003022439     NaN
# 2    한식/백반/한정식   I56111  ...  2714011000110210000008286   문화아파트
# 3       꽃집/꽃배달   G47851  ...  2723011200100380015000001     NaN
# 4      족발/보쌈전문   I56111  ...  2723010200100200001007645  스펙트럼시티
#
#                    도로명주소   구우편번호    신우편번호  동정보  층정보  호정보          경도  \
# ...

# %%
category = data['상권업종대분류명'].value_counts()

category.keys()
for i in category.keys():
    print(i)
# Out:
# 음식
# 소매
# 생활서비스
# 학문/교육
# 부동산
# 관광/여가/오락
# 스포츠
# 숙박

# %%
category = data['상권업종대분류명'].value_counts()

store = {}
for i in category.keys():
    store[i] = data.loc[data['상권업종대분류명']==i]
store['음식'].head()
# Out:
#       상가업소번호     상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 0   20547760  옛날포장마차  NaN         Q       음식       Q09     유흥주점    Q09A02
# 2   20549469    박가냉면  NaN         Q       음식       Q01       한식    Q01A01
# 4   17174605  장충동왕족발  NaN         Q       음식       Q01       한식    Q01A08
# 13  20084439    굽네치킨  지산점         Q       음식       Q05   닭/오리요리    Q05A08
# 20  20552347    닭S포차  NaN         Q       음식       Q09     유흥주점    Q09A02
#
#      상권업종소분류명 표준산업분류코드  ...                     건물관리번호     건물명  \
# 0    소주방/포장마차   I56219  ...  2717010200113270001025963     NaN
# 2   한식/백반/한정식   I56111  ...  2714011000110210000008286   문화아파트
# 4     족발/보쌈전문   I56111  ...  2723010200100200001007645  스펙트럼시티
# 13  후라이드/양념치킨   I56193  ...  2726011200112720002004141   에덴아파트
# 20   소주방/포장마차   I56219  ...  2717010200105040015007748     NaN
#
#                   도로명주소   구우편번호    신우편번호  동정보  층정보  호정보          경도         위도
# ...

# %%
Franchise = store['음식']['상호명'].value_counts()

Franchise[1:21]
# Out:
# 이디야커피       71
# BBQ치킨       69
# 파리바게뜨       66
# 스타벅스        61
# BHC치킨       60
# 투썸플레이스      57
# 나           53
# 교촌치킨        42
# 서울떡집        40
# 더리터         39
# 호식이두마리치킨    38
# 봄봄테이크아웃     36
# 본죽          36
# 땅땅치킨        35
# 처갓집양념치킨     34
# 몬스터커피       34
# 선비꼬마김밥      34
# 청와삼대        33
# 김밥천국        33
# 배스킨라빈스31    32
# Name: 상호명, dtype: int64

# %%
franchise = Franchise[1:21].keys()

print(franchise)
# Out:
# Index(['이디야커피', 'BBQ치킨', '파리바게뜨', '스타벅스', 'BHC치킨', '투썸플레이스', '나', '교촌치킨',
#        '서울떡집', '더리터', '호식이두마리치킨', '봄봄테이크아웃', '본죽', '땅땅치킨', '처갓집양념치킨', '몬스터커피',
#        '선비꼬마김밥', '청와삼대', '김밥천국', '배스킨라빈스31'],
#       dtype='object')

# %%
이디야 = store['음식'].loc[store['음식']['상호명']=='이디야커피']
이디야_위경도 = 이디야[['위도', '경도']]

# %%
이디야_위경도
# Out:
#               위도          경도
# 2673   35.852487  128.634550
# 7349   35.866899  128.624212
# 9697   35.780992  128.441570
# 12556  35.883292  128.622889
# 13326  35.871970  128.728966
# ...          ...         ...
# 93880  35.863694  128.597003
# 94055  35.864304  128.599244
# 95452  35.874250  128.618079
# 97025  35.831943  128.629959
# 98391  35.860034  128.623682
#
# [71 rows x 2 columns]

# %%
m = folium.Map(location=[37.515118,126.918062],zoom_start=14)

# %%
folium.Marker([37.515118,126.918062]).add_to(m)

# %%
for 위도, 경도 in zip(이디야['위도'],이디야['경도']):
  folium.Marker([위도,경도]).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
스타벅스 = store['음식'].loc[store['음식']['상호명']=='스타벅스']
스타벅스_위경도 = 스타벅스[['위도', '경도']]

# %%
for 위도, 경도 in zip(스타벅스['위도'],스타벅스['경도']):
  folium.Marker([위도,경도]).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
